# %%
import pandas as pd
df = pd.read_csv('medals.csv', skiprows = 4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df['NOC'] = df['NOC'].str.lower()

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  hun    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  aut    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  gre    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  gre    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  gre    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df['Gender'] = df['Gender'].str.upper()

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  hun    MEN
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  aut    MEN
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  gre    MEN
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  gre    MEN
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  gre    MEN
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.isnull().values.any()
# Out:
# False

# %%
#df["Athlete"]= df["Athlete"].str.split(",", n = 1, expand = True) 
#type(df['Sport'])
df['Sport'].to_string()
# Out:
# '0                 Aquatics\n1                 Aquatics\n2                 Aquatics\n3                 Aquatics\n4                 Aquatics\n5                 Aquatics\n6                 Aquatics\n7                 Aquatics\n8                 Aquatics\n9                 Aquatics\n10                Aquatics\n11               Athletics\n12               Athletics\n13               Athletics\n14               Athletics\n15               Athletics\n16               Athletics\n17               Athletics\n18               Athletics\n19               Athletics\n20               Athletics\n21               Athletics\n22               Athletics\n23               Athletics\n24               Athletics\n25               Athletics\n26               Athletics\n27               Athletics\n28               Athletics\n29               Athletics\n30               Athletics\n31               Athletics\n32               Athletics\n33               Athletics\n34               Athletics\n35               
# ...

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  hun    MEN
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  aut    MEN
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  gre    MEN
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  gre    MEN
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  gre    MEN
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
import pandas as pd
df = pd.read_csv('medals.csv', skiprows = 4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df['Athlete'] = df['Athlete'].str.lower()
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       hajos, alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    herschmann, otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   drivas, dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  malokinis, ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  chasapis, spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df['Athlete'] = df['Athlete'].to_string()

# %%
df['Athlete'].dtype
# Out:
# dtype('O')
