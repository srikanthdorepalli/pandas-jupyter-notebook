# %%
import pandas as pd
df = pd.read_csv('medals.csv', skiprows = 4)
newdf = df.set_index('Sport')
print(newdf)
# Out:
#               City  Edition       Discipline                      Athlete  \
# Sport
# Aquatics    Athens     1896         Swimming                HAJOS, Alfred
# Aquatics    Athens     1896         Swimming             HERSCHMANN, Otto
# Aquatics    Athens     1896         Swimming            DRIVAS, Dimitrios
# Aquatics    Athens     1896         Swimming           MALOKINIS, Ioannis
# Aquatics    Athens     1896         Swimming           CHASAPIS, Spiridon
# Aquatics    Athens     1896         Swimming        CHOROPHAS, Efstathios
# Aquatics    Athens     1896         Swimming                HAJOS, Alfred
# Aquatics    Athens     1896         Swimming             ANDREOU, Joannis
# Aquatics    Athens     1896         Swimming        CHOROPHAS, Efstathios
# Aquatics    Athens     1896         Swimming                NEUMANN, Paul
# Aquatics    Athens     1896         Swimming            PEPANOS, Antonios
# Athletics   Athens     1896        Athletics                LANE, Francis
# ...

# %%
'''DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)

keys: Column name or list of a column name.
drop: It’s a Boolean value which drops the column used for the index if True.
append: It appends the column to the existing index column if True.
inplace: It makes the changes in the DataFrame if True.
verify_integrity: It checks the new index column for duplicates if True.'''
# Out:
# 'DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)\n\nkeys: Column name or list of a column name.\ndrop: It’s a Boolean value which drops the column used for the index if True.\nappend: It appends the column to the existing index column if True.\ninplace: It makes the changes in the DataFrame if True.\nverify_integrity: It checks the new index column for duplicates if True.'

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.set_index('Sport', inplace = True)
print(type(df.index))
print(df)
# Out:
# <class 'pandas.core.indexes.base.Index'>
#               City  Edition       Discipline                      Athlete  \
# Sport
# Aquatics    Athens     1896         Swimming                HAJOS, Alfred
# Aquatics    Athens     1896         Swimming             HERSCHMANN, Otto
# Aquatics    Athens     1896         Swimming            DRIVAS, Dimitrios
# Aquatics    Athens     1896         Swimming           MALOKINIS, Ioannis
# Aquatics    Athens     1896         Swimming           CHASAPIS, Spiridon
# Aquatics    Athens     1896         Swimming        CHOROPHAS, Efstathios
# Aquatics    Athens     1896         Swimming                HAJOS, Alfred
# Aquatics    Athens     1896         Swimming             ANDREOU, Joannis
# Aquatics    Athens     1896         Swimming        CHOROPHAS, Efstathios
# Aquatics    Athens     1896         Swimming                NEUMANN, Paul
# Aquatics    Athens     1896         Swimming            PEPANOS, Antonios
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#        index     City  Edition      Sport       Discipline  \
# 0          0   Athens     1896   Aquatics         Swimming
# 1          1   Athens     1896   Aquatics         Swimming
# 2          2   Athens     1896   Aquatics         Swimming
# 3          3   Athens     1896   Aquatics         Swimming
# 4          4   Athens     1896   Aquatics         Swimming
# 5          5   Athens     1896   Aquatics         Swimming
# 6          6   Athens     1896   Aquatics         Swimming
# 7          7   Athens     1896   Aquatics         Swimming
# 8          8   Athens     1896   Aquatics         Swimming
# 9          9   Athens     1896   Aquatics         Swimming
# 10        10   Athens     1896   Aquatics         Swimming
# 11        11   Athens     1896  Athletics        Athletics
# 12        12   Athens     1896  Athletics        Athletics
# 13        13   Athens     1896  Athletics        Athletics
# 14        14   Athens     1896  Athletics        Athletics
# ...

# %%
#other examples
df = pd.DataFrame({'month': [1, 4, 7, 10],'year': [2012, 2014, 2013, 2014],'sale': [55, 40, 84, 31]})
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df.set_index('month', inplace = True)
df
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
df.reset_index(inplace = True)
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df.set_index(['month','year'] , inplace = True)
df
# Out:
#             sale
# month year
# 1     2012    55
# 4     2014    40
# 7     2013    84
# 10    2014    31

# %%
df.reset_index(inplace = True)
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
print(df.set_index([pd.Index([1,2,3,4]), 'year']))
# Out:
#         month  sale
#   year
# 1 2012      1    55
# 2 2014      4    40
# 3 2013      7    84
# 4 2014     10    31

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    index  month  year  sale
# 0      0      1  2012    55
# 1      1      4  2014    40
# 2      2      7  2013    84
# 3      3     10  2014    31

# %%
df.reset_index(drop = True,inplace = True)
df
# Out:
#    level_0  index  month  year  sale
# 0        0      0      1  2012    55
# 1        1      1      4  2014    40
# 2        2      2      7  2013    84
# 3        3      3     10  2014    31

# %%
#To drop a single column from pandas dataframe, we need to provide the name of the column to be dropped as a list as an argument to drop function.
df.drop(['level_0'], axis = 1, inplace = True)
df
# Out:
#    index  month  year  sale
# 0      0      1  2012    55
# 1      1      4  2014    40
# 2      2      7  2013    84
# 3      3     10  2014    31

# %%
# to drop a row, give axis = 0 and mention index of row to be removed
df.drop([1,3], axis = 0, inplace = True)
df
# Out:
#    index  month  year  sale
# 0      0      1  2012    55
# 2      2      7  2013    84

# %%
newdf = pd.DataFrame({'name': ['sri', 'raj', 'lex'], 'age':[25,24,28], 'salary':[50000,30000,80000]})
newdf
# Out:
#   name  age  salary
# 0  sri   25   50000
# 1  raj   24   30000
# 2  lex   28   80000

# %%
print(newdf.set_index('name'))
# Out:
#       age  salary
# name
# sri    25   50000
# raj    24   30000
# lex    28   80000

# %%
newdf.set_index('name', append = True, verify_integrity = True, inplace = True)
newdf
# Out:
#         age  salary
#   name
# 0 sri    25   50000
# 1 raj    24   30000
# 2 lex    28   80000
