# %%
import pandas as pd
df = pd.read_csv("nba.csv", header = None)
print(df)
# Out:
#                            0                       1       2         3     4  \
# 0                       Name                    Team  Number  Position   Age
# 1              Avery Bradley          Boston Celtics     0.0        PG  25.0
# 2                Jae Crowder          Boston Celtics    99.0        SF  25.0
# 3               John Holland          Boston Celtics    30.0        SG  27.0
# 4                R.J. Hunter          Boston Celtics    28.0        SG  22.0
# 5              Jonas Jerebko          Boston Celtics     8.0        PF  29.0
# 6               Amir Johnson          Boston Celtics    90.0        PF  29.0
# 7              Jordan Mickey          Boston Celtics    55.0        PF  21.0
# 8               Kelly Olynyk          Boston Celtics    41.0         C  25.0
# 9               Terry Rozier          Boston Celtics    12.0        PG  22.0
# 10              Marcus Smart          Boston Celtics    36.0        PG  22.0
# ...

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print(df)
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print(df)
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Drop rows with label 0
#df = df.drop(0)
#print(df)
#print(df.T)  --->Traverses dataframe (rows to columns)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
#df = pd.read_csv('nba.csv')
df = pd.read_csv('nba.csv', index_col = 'Name')
#print(df[['Name','Position','Age']])
#using_loc = df.loc[['Evan Turner','Rudy Gobert'], ['Team','Age']]
#using_loc = df.loc['Evan Turner':'Markel Brown', 'Team':'Age']
using_loc = df.loc[:,['Team','Age']]
#using_iloc = df.iloc[[11,12,15],[1,5]]
#using_iloc = df.iloc[11:13,2:4]
print(using_loc)
# Out:
#                                            Team   Age
# Name
# Avery Bradley                    Boston Celtics  25.0
# Jae Crowder                      Boston Celtics  25.0
# John Holland                     Boston Celtics  27.0
# R.J. Hunter                      Boston Celtics  22.0
# Jonas Jerebko                    Boston Celtics  29.0
# Amir Johnson                     Boston Celtics  29.0
# Jordan Mickey                    Boston Celtics  21.0
# Kelly Olynyk                     Boston Celtics  25.0
# Terry Rozier                     Boston Celtics  22.0
# Marcus Smart                     Boston Celtics  22.0
# Jared Sullinger                  Boston Celtics  24.0
# Isaiah Thomas                    Boston Celtics  27.0
# Evan Turner                      Boston Celtics  27.0
# James Young                      Boston Celtics  20.0
# Tyler Zeller                     Boston Celtics  26.0
# Bojan Bogdanovic                  Brooklyn Nets  27.0
# ...

# %%
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
#adding a column
df['range'] = [i for i in range(0,len(df))]
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
#removing a column
del df['range']
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...
