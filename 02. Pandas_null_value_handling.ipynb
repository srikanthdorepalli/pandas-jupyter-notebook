# %%
import pandas as pd

# %%
my_car = {'name':['audi','benz','suzuki'], 'color': ['black','white','red'], 'price': [None,30,10]}
mydf = pd.DataFrame(my_car)
mydf
# Out:
#      name  color  price
# 0    audi  black    NaN
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
mydf.isnull()
# Out:
#     name  color  price
# 0  False  False   True
# 1  False  False  False
# 2  False  False  False

# %%
price_null = pd.isnull(mydf.price)
type(price_null)
# Out:
# pandas.core.series.Series

# %%
mydf[price_null]
# Out:
#    name  color  price
# 0  audi  black    NaN

# %%
mydf.notnull()
# Out:
#    name  color  price
# 0  True   True  False
# 1  True   True   True
# 2  True   True   True

# %%
not_null = pd.notnull(mydf.price)
not_null
# Out:
# 0    False
# 1     True
# 2     True
# Name: price, dtype: bool

# %%
mydf[not_null]
# Out:
#      name  color  price
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
mydf[mydf.price.notnull()]
# Out:
#      name  color  price
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
empdf = pd.read_csv('employees.csv')
#empdf.head()
empdf.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
empdf[empdf.Salary.isnull()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
#newempdf = empdf[empdf.Gender.isnull()]
newempdf = empdf[empdf['First Name'].isnull()]
newempdf.head()
#newempdf.Salary
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7         NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 23        NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 25        NaN    Male  10/8/2012         1:12 AM   37076   18.576
# 32        NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 39        NaN    Male  1/29/2016         2:33 AM  122173    7.797
#
#    Senior Management             Team
# 7                NaN          Finance
# 23               NaN              NaN
# 25               NaN  Client Services
# 32               NaN              NaN
# 39               NaN  Client Services

# %%
mydf
# Out:
#      name  color  price
# 0    audi  black    NaN
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
mydf.fillna(0)
#mydf.fillna(method = 'pad')   #fill with previuos value
#mydf.fillna(method = 'bfill') #fill with next value
# Out:
#      name  color  price
# 0    audi  black    0.0
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
mydf.fillna(0, inplace = True)

# %%
mydf
# Out:
#      name  color  price
# 0    audi  black    0.0
# 1    benz  white   30.0
# 2  suzuki    red   10.0

# %%
empdf[1:25]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7         NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# ...

# %%
empdf['Gender'].fillna('No_Gender', inplace = True)

# %%
empdf[empdf['Gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
empdf[20:23]
# Out:
#    First Name     Gender Start Date Last Login Time  Salary  Bonus %  \
# 20       Lois  No_Gender  4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male   9/5/1995         2:12 AM  100612   13.645
# 22     Joshua  No_Gender   3/8/2012         1:58 AM   90816   18.816
#
#    Senior Management             Team
# 20              True            Legal
# 21             False        Marketing
# 22              True  Client Services

# %%
#empdf.iloc[20]
empdf[1:10]
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# 4              True       Client Services
# 5             False                 Legal
# 6              True               Product
# ...

# %%
empdf['First Name'].fillna('No_Name', inplace = True)

# %%
empdf[empdf['First Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
empdf['Team'].replace(to_replace = 'NaN', value = 'No_Team')
# Out:
# 0                 Marketing
# 1                       NaN
# 2                   Finance
# 3                   Finance
# 4           Client Services
# 5                     Legal
# 6                   Product
# 7                   Finance
# 8               Engineering
# 9      Business Development
# 10                      NaN
# 11                    Legal
# 12          Human Resources
# 13                    Sales
# 14                  Finance
# 15                  Product
# 16          Human Resources
# 17                  Product
# 18          Client Services
# 19                  Product
# 20                    Legal
# 21                Marketing
# 22          Client Services
# 23                      NaN
# 24          Client Services
# 25          Client Services
# 26                Marketing
# 27                    Legal
# 28          Client Services
# 29                    Legal
#                ...
# 970                 Product
# 971    Business Development
# ...

# %%
empdf[1:10]
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7    No_Name  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# 4              True       Client Services
# 5             False                 Legal
# 6              True               Product
# ...

# %%
import numpy as np

# %%
empdf['Team'].replace(to_replace = np.nan, value = 'No_Team')
# Out:
# 0                 Marketing
# 1                   No_Team
# 2                   Finance
# 3                   Finance
# 4           Client Services
# 5                     Legal
# 6                   Product
# 7                   Finance
# 8               Engineering
# 9      Business Development
# 10                  No_Team
# 11                    Legal
# 12          Human Resources
# 13                    Sales
# 14                  Finance
# 15                  Product
# 16          Human Resources
# 17                  Product
# 18          Client Services
# 19                  Product
# 20                    Legal
# 21                Marketing
# 22          Client Services
# 23                  No_Team
# 24          Client Services
# 25          Client Services
# 26                Marketing
# 27                    Legal
# 28          Client Services
# 29                    Legal
#                ...
# 970                 Product
# 971    Business Development
# ...

# %%
before_remove_null = len(empdf)

# %%
empdf.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
#empdf.dropna()  # drop rows with at least one Nan value (Null value)
#empdf.dropna(how = 'all')  #Dropping rows if all values in that row are missing.
#df.dropna(axis = 1)  # drop a columns which have at least 1 missing values
#data.dropna(axis = 0, how ='any')  #Dropping Rows with at least 1 null value 
After_remove_null = len(empdf.dropna())

# %%
before_remove_null-After_remove_null
# Out:
# 101
